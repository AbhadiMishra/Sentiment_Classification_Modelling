# %% [markdown]
# ## <b> <i> Testing on data <b> <i>

# %%
import re
import numpy as np
from joblib import load

# %%
file_path_ = r"WhatsAppChat.txt"

# %%
# Function to extract date and time
def date_time(s):
    pattern = (
        r"^([0-9]+)(\/)([0-9]+)(\/)([0-9]+), ([0-9]+):([0-9]+)([ ]|.)?(AM|PM|am|pm)? -"
    )
    result = re.match(pattern, s)
    if result:
        return True
    return False


# Function to extract author
def messenger(s):
    s = s.split(":")
    if len(s) == 2:
        return True
    else:
        return False


# Function to extract message data
def message_data(line):
    splitline = line.split(" - ")
    dateTime = splitline[0]
    date, time = dateTime.split(", ")
    message = " ".join(splitline[1:])
    if messenger(message):
        splitmessage = message.split(": ")
        author = splitmessage[0]
        message = " ".join(splitmessage[1:])
    else:
        author = None
    return date, time, author, message

#dummy tuple =================================================
data = []

#main block =================================================
try:
 with open(file_path_, encoding="utf-8") as fp:
    fp.readline()
    messageBuffer = []
    date, time, author = None, None, None
    while True:
        line = fp.readline()
        if not line:
            break
        line = line.strip()
        if date_time(line):
            if len(messageBuffer) > 0:
                data.append([date, time, author, ' '.join(messageBuffer)])
            messageBuffer.clear()
            date, time, author, message = message_data(line)
            messageBuffer.append(message)
        else:
            messageBuffer.append(line)

except Exception as e:
        print(f"Exception caught {e}")

# %%
import pandas as pd
df = pd.DataFrame(data, columns=['Date', 'Time', 'Author', 'Message'])
text = df["Message"].tolist()

# %% [markdown]
# # Model Predictions

# %%
mnb_model = load('pipeline_mnb1.joblib')
svm_model = load("pipeline_svm.joblib")
lr_model = load("pipeline_lr.joblib")
rf_model = load("pipeline_rf.joblib")
dt_model = load("pipeline_dt.joblib")
knn_model = load("pipeline_knn.joblib")
mnb799 = load("multinomialNB799.joblib")
mlp_model = load("pipeline_mlp.joblib")
gbc_model = load("pipeline_gbc.joblib")
model_abc = load("pipeline_abc.joblib")

# %%
import pandas as pd

models = [ mnb_model, svm_model, lr_model, rf_model, dt_model, knn_model, mnb799, mlp_model, gbc_model, model_abc]

messages = df["Message"]

sentiment_labels = {-1: "negative", 0: "neutral", 1: "positive"}


for model in models:
    print("Using model:" + str(model))
    
    predictions = model.predict(messages)
    
   
    predicted_sentiments = [sentiment_labels[pred] for pred in predictions]
    

    result_df = pd.DataFrame({"Message": messages, "Sentiment": predicted_sentiments})
    result_df.reset_index(drop=True, inplace=True)

    print(result_df.head(50))
    print("----------------------------------------------------------------------------------")
# Out:
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('mnb', MultinomialNB(alpha=0.5))])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk   neutral
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk   neutral
# 4                                      Bhulna mt bhai   neutral
# 5                                         Sbko bhejdo   neutral
# 6                             Aur groups me mt bhejna  negative
# 7                                                 Okk   neutral
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok   neutral
# 10                                       12 baje aana   neutral
# 11                                                Okk   neutral
# 12                                            Aoo gay  negative
# 13                                             Aao be   neutral
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the  negative
# 16  Sudhir Yadav. 00001278532 is inviting you to a...   neutral
# 17  Sudhir: Topic: 12th students only Time: Apr 19...   neutral
# 18                                         Chal jutha   neutral
# 19                                    <Media omitted>   neutral
# 20                                      Subscribe kri   neutral
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.   neutral
# 23                                                Mst   neutral
# 24               Sudhir: https://youtu.be/4WuALZRLJF0   neutral
# 25                  Subscribe kara do dost ko bhej kr   neutral
# 26                                               Sare   neutral
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa   neutral
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse   neutral
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya   neutral
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga  positive
# 39                      Abhi karo 💯 pahuchne wala hai   neutral
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>   neutral
# 45                                    <Media omitted>   neutral
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  positive
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()), ('svc', SVC())])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk  negative
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk  negative
# 4                                      Bhulna mt bhai   neutral
# 5                                         Sbko bhejdo   neutral
# 6                             Aur groups me mt bhejna  negative
# 7                                                 Okk  negative
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok   neutral
# 10                                       12 baje aana   neutral
# 11                                                Okk  negative
# 12                                            Aoo gay  negative
# 13                                             Aao be  negative
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the   neutral
# 16  Sudhir Yadav. 00001278532 is inviting you to a...   neutral
# 17  Sudhir: Topic: 12th students only Time: Apr 19...   neutral
# 18                                         Chal jutha   neutral
# 19                                    <Media omitted>  negative
# 20                                      Subscribe kri  negative
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.   neutral
# 23                                                Mst   neutral
# 24               Sudhir: https://youtu.be/4WuALZRLJF0   neutral
# 25                  Subscribe kara do dost ko bhej kr   neutral
# 26                                               Sare   neutral
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa   neutral
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse   neutral
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya   neutral
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga  positive
# 39                      Abhi karo 💯 pahuchne wala hai   neutral
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>  negative
# 45                                    <Media omitted>  negative
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  positive
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('lr',
#                  LogisticRegression(class_weight='balanced', max_iter=60000,
#                                     random_state=20))])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk  negative
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk  negative
# 4                                      Bhulna mt bhai  negative
# 5                                         Sbko bhejdo   neutral
# 6                             Aur groups me mt bhejna  negative
# 7                                                 Okk  negative
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok   neutral
# 10                                       12 baje aana   neutral
# 11                                                Okk  negative
# 12                                            Aoo gay  negative
# 13                                             Aao be  negative
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the   neutral
# 16  Sudhir Yadav. 00001278532 is inviting you to a...   neutral
# 17  Sudhir: Topic: 12th students only Time: Apr 19...   neutral
# 18                                         Chal jutha  negative
# 19                                    <Media omitted>  negative
# 20                                      Subscribe kri  negative
# 21                                         Kon banaya  positive
# 22                               Or bhai kya ho raha.   neutral
# 23                                                Mst  positive
# 24               Sudhir: https://youtu.be/4WuALZRLJF0   neutral
# 25                  Subscribe kara do dost ko bhej kr   neutral
# 26                                               Sare  negative
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa  negative
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse   neutral
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya   neutral
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga  positive
# 39                      Abhi karo 💯 pahuchne wala hai   neutral
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>  negative
# 45                                    <Media omitted>  negative
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  positive
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('rf',
#                  RandomForestClassifier(n_estimators=300, n_jobs=-1,
#                                         random_state=20))])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk  negative
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk  negative
# 4                                      Bhulna mt bhai   neutral
# 5                                         Sbko bhejdo  negative
# 6                             Aur groups me mt bhejna   neutral
# 7                                                 Okk  negative
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok  positive
# 10                                       12 baje aana   neutral
# 11                                                Okk  negative
# 12                                            Aoo gay  negative
# 13                                             Aao be   neutral
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the   neutral
# 16  Sudhir Yadav. 00001278532 is inviting you to a...   neutral
# 17  Sudhir: Topic: 12th students only Time: Apr 19...   neutral
# 18                                         Chal jutha   neutral
# 19                                    <Media omitted>  negative
# 20                                      Subscribe kri  negative
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.   neutral
# 23                                                Mst  negative
# 24               Sudhir: https://youtu.be/4WuALZRLJF0  negative
# 25                  Subscribe kara do dost ko bhej kr  positive
# 26                                               Sare  negative
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa  negative
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse   neutral
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya  positive
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga   neutral
# 39                      Abhi karo 💯 pahuchne wala hai  negative
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>  negative
# 45                                    <Media omitted>  negative
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  positive
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()), ('dt', DecisionTreeClassifier())])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk  negative
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk  negative
# 4                                      Bhulna mt bhai   neutral
# 5                                         Sbko bhejdo  negative
# 6                             Aur groups me mt bhejna   neutral
# 7                                                 Okk  negative
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok  positive
# 10                                       12 baje aana   neutral
# 11                                                Okk  negative
# 12                                            Aoo gay  negative
# 13                                             Aao be   neutral
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the   neutral
# 16  Sudhir Yadav. 00001278532 is inviting you to a...  negative
# 17  Sudhir: Topic: 12th students only Time: Apr 19...   neutral
# 18                                         Chal jutha   neutral
# 19                                    <Media omitted>  negative
# 20                                      Subscribe kri  negative
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.  negative
# 23                                                Mst  negative
# 24               Sudhir: https://youtu.be/4WuALZRLJF0   neutral
# 25                  Subscribe kara do dost ko bhej kr   neutral
# 26                                               Sare  negative
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa   neutral
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse   neutral
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya  positive
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga   neutral
# 39                      Abhi karo 💯 pahuchne wala hai  negative
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>  negative
# 45                                    <Media omitted>  negative
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir   neutral
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('knn', KNeighborsClassifier(n_neighbors=10))])
#                                               Message Sentiment
# 0                                      Sabko bhej  do  negative
# 1                                                 Okk  negative
# 2                         Abhinav log ko sbko bhej do  negative
# 3                                                 Okk  negative
# 4                                      Bhulna mt bhai  negative
# 5                                         Sbko bhejdo   neutral
# 6                             Aur groups me mt bhejna  negative
# 7                                                 Okk  negative
# 8                                  Abhinav do bhej do  negative
# 9                                                  Ok  positive
# 10                                       12 baje aana   neutral
# 11                                                Okk  negative
# 12                                            Aoo gay  negative
# 13                                             Aao be   neutral
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the  negative
# 16  Sudhir Yadav. 00001278532 is inviting you to a...  negative
# 17  Sudhir: Topic: 12th students only Time: Apr 19...  negative
# 18                                         Chal jutha   neutral
# 19                                    <Media omitted>  negative
# 20                                      Subscribe kri  negative
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.  negative
# 23                                                Mst  negative
# 24               Sudhir: https://youtu.be/4WuALZRLJF0  negative
# 25                  Subscribe kara do dost ko bhej kr  negative
# 26                                               Sare  negative
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru  negative
# 29                                         Tumari naa  negative
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse  negative
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9  negative
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya   neutral
# 37                       Tm bhi apne dosto ko bhej d9  negative
# 38                                       Okk kar duga  negative
# 39                      Abhi karo 💯 pahuchne wala hai  negative
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do  negative
# 42                                    Subscribe kr de  negative
# 43                                          Seriously  negative
# 44                                    <Media omitted>  negative
# 45                                    <Media omitted>  negative
# 46                                    Abe Mia kaha hu  negative
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  negative
# 49                           Ki zoom I'd aur password  negative
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer(max_features=60000)),
#                 ('nb', MultinomialNB(alpha=0.3))])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk   neutral
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk   neutral
# 4                                      Bhulna mt bhai   neutral
# 5                                         Sbko bhejdo   neutral
# 6                             Aur groups me mt bhejna  negative
# 7                                                 Okk   neutral
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok   neutral
# 10                                       12 baje aana   neutral
# 11                                                Okk   neutral
# 12                                            Aoo gay  negative
# 13                                             Aao be   neutral
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the  negative
# 16  Sudhir Yadav. 00001278532 is inviting you to a...   neutral
# 17  Sudhir: Topic: 12th students only Time: Apr 19...   neutral
# 18                                         Chal jutha   neutral
# 19                                    <Media omitted>   neutral
# 20                                      Subscribe kri   neutral
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.   neutral
# 23                                                Mst   neutral
# 24               Sudhir: https://youtu.be/4WuALZRLJF0   neutral
# 25                  Subscribe kara do dost ko bhej kr   neutral
# 26                                               Sare   neutral
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa   neutral
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse   neutral
# 32                                           Tekk hsi  positive
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya   neutral
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga  positive
# 39                      Abhi karo 💯 pahuchne wala hai  negative
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>   neutral
# 45                                    <Media omitted>   neutral
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  negative
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('mlp',
#                  MLPClassifier(hidden_layer_sizes=(100, 50), max_iter=1000))])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk  negative
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk  negative
# 4                                      Bhulna mt bhai  positive
# 5                                         Sbko bhejdo   neutral
# 6                             Aur groups me mt bhejna  negative
# 7                                                 Okk  negative
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok  positive
# 10                                       12 baje aana   neutral
# 11                                                Okk  negative
# 12                                            Aoo gay  negative
# 13                                             Aao be  positive
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the  negative
# 16  Sudhir Yadav. 00001278532 is inviting you to a...   neutral
# 17  Sudhir: Topic: 12th students only Time: Apr 19...   neutral
# 18                                         Chal jutha  negative
# 19                                    <Media omitted>  negative
# 20                                      Subscribe kri  negative
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.  positive
# 23                                                Mst  positive
# 24               Sudhir: https://youtu.be/4WuALZRLJF0   neutral
# 25                  Subscribe kara do dost ko bhej kr  positive
# 26                                               Sare   neutral
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa   neutral
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse   neutral
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6  positive
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya  positive
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga  positive
# 39                      Abhi karo 💯 pahuchne wala hai  negative
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>  negative
# 45                                    <Media omitted>  negative
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  positive
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('gbc',
#                  GradientBoostingClassifier(learning_rate=0.2, max_depth=5,
#                                             n_estimators=500))])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk  negative
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk  negative
# 4                                      Bhulna mt bhai   neutral
# 5                                         Sbko bhejdo   neutral
# 6                             Aur groups me mt bhejna  negative
# 7                                                 Okk  negative
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok  positive
# 10                                       12 baje aana   neutral
# 11                                                Okk  negative
# 12                                            Aoo gay  negative
# 13                                             Aao be  negative
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the   neutral
# 16  Sudhir Yadav. 00001278532 is inviting you to a...   neutral
# 17  Sudhir: Topic: 12th students only Time: Apr 19...   neutral
# 18                                         Chal jutha   neutral
# 19                                    <Media omitted>  negative
# 20                                      Subscribe kri  negative
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.   neutral
# 23                                                Mst  negative
# 24               Sudhir: https://youtu.be/4WuALZRLJF0  negative
# 25                  Subscribe kara do dost ko bhej kr   neutral
# 26                                               Sare  negative
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa  negative
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse   neutral
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya   neutral
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga   neutral
# 39                      Abhi karo 💯 pahuchne wala hai   neutral
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>  negative
# 45                                    <Media omitted>  negative
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  positive
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
# Using model:Pipeline(steps=[('tfidf', TfidfVectorizer()),
#                 ('abc',
#                  AdaBoostClassifier(learning_rate=0.5, n_estimators=1000,
#                                     random_state=0))])
#                                               Message Sentiment
# 0                                      Sabko bhej  do   neutral
# 1                                                 Okk  negative
# 2                         Abhinav log ko sbko bhej do   neutral
# 3                                                 Okk  negative
# 4                                      Bhulna mt bhai   neutral
# 5                                         Sbko bhejdo  negative
# 6                             Aur groups me mt bhejna  negative
# 7                                                 Okk  negative
# 8                                  Abhinav do bhej do   neutral
# 9                                                  Ok   neutral
# 10                                       12 baje aana   neutral
# 11                                                Okk  negative
# 12                                            Aoo gay  negative
# 13                                             Aao be  negative
# 14                                                Nhi  negative
# 15                          Kahe zoom se bhag gai the   neutral
# 16  Sudhir Yadav. 00001278532 is inviting you to a...   neutral
# 17  Sudhir: Topic: 12th students only Time: Apr 19...  negative
# 18                                         Chal jutha  negative
# 19                                    <Media omitted>  negative
# 20                                      Subscribe kri  negative
# 21                                         Kon banaya   neutral
# 22                               Or bhai kya ho raha.   neutral
# 23                                                Mst  negative
# 24               Sudhir: https://youtu.be/4WuALZRLJF0  negative
# 25                  Subscribe kara do dost ko bhej kr   neutral
# 26                                               Sare  negative
# 27                                            Kya hai   neutral
# 28                   Or pdhai ho rahi hogi kubb tumru   neutral
# 29                                         Tumari naa  negative
# 30                                                Nhi  negative
# 31                   Channel subscribe karwa do sabse  negative
# 32                                           Tekk hsi  negative
# 33                                       Bhejo pahpe6   neutral
# 34                                       Bhej do sbk9   neutral
# 35                          Aby tum hi send kar doona   neutral
# 36                                    Abe mai kr diya   neutral
# 37                       Tm bhi apne dosto ko bhej d9   neutral
# 38                                       Okk kar duga   neutral
# 39                      Abhi karo 💯 pahuchne wala hai   neutral
# 40                                           Tekk hai   neutral
# 41                         Bhai isko sabhi ko bhej do   neutral
# 42                                    Subscribe kr de   neutral
# 43                                          Seriously  negative
# 44                                    <Media omitted>  negative
# 45                                    <Media omitted>  negative
# 46                                    Abe Mia kaha hu   neutral
# 47                                         Dekh hobay   neutral
# 48                                         Rajesh sir  positive
# 49                           Ki zoom I'd aur password   neutral
# ----------------------------------------------------------------------------------
